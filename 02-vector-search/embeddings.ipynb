# %% [markdown]
# #### Choosing a model for embeddings

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %% [markdown]
# #### Trying it with simple examples

# %%
# Convert the query into numbers
q1 = "Can I still join the course after the start date?"
v1 = model.encode(q1)

# %%
# Convert the document into numbers
d  = "You don't need to register. You're accepted. You can also just start learning and submitting homework without registering."
dv = model.encode(d)

# %%
# Compare the query against the document using dot product
v1.dot(dv)
# Out:
# np.float32(0.32332397)

# %%
# Now we try an unrelated query
q2 = "How to install Docker on Windows?"
v2 = model.encode(q2)

# %%
v2.dot(dv)
# Out:
# np.float32(0.019730438)
