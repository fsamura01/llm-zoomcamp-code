# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

# %%
documents = load_faq_data()
print(f"Loaded {len(documents)} documents")
index = build_index(documents)
# Out:
# Loaded 1342 documents

# %%
import os

# %%
openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)
#print(vars(assistant))

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes—you can still join the course. Just keep in mind that if you’d like to earn a certificate, you’ll need to submit your project before the submission window closes.
